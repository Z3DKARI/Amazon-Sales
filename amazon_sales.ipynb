# %% [markdown]
# # Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# # Configuration

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Import Dataset

# %%
sales = pd.read_csv('dataset/amazon.csv')
sales.head(5)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# # Data Understanding

# %%
# Data Information
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
print(f'This dataset have {sales.shape[0]} Rows and {sales.shape[1]} Columns in total')
# Out:
# This dataset have 1465 Rows and 16 Columns in total

# %% [markdown]
# ### Summary :
# * Dataset Shape is 1464 x 16
# * Data Types are all object, expected columns to be numerics are 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count'
# * There is some missing value on columns 'rating_count'

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Change all the expected numerics columns/features from object

# %%
# Discounted Price
sales['discounted_price'] = sales['discounted_price'].replace('₹', '', regex=True).replace(',', '', regex=True).astype(float)

# Actual Price
sales['actual_price'] = sales['actual_price'].replace('₹', '', regex=True).replace(',', '', regex=True).astype(float)

# Discounted Percentage
sales['discount_percentage'] = sales['discount_percentage'].replace('%', '', regex=True).astype(float) / 100

# Rating Count
sales['rating_count'] = sales['rating_count'].replace(',','',regex=True).astype(float)

# %% [markdown]
# For the 'rating' we need to inspect a little more cause when we just convert to float it's give an error that there some non number value in the columns

# %%
sales['rating'].value_counts().reset_index()
# Out:
#    rating  count
# 0     4.1    244
# 1     4.3    230
# 2     4.2    228
# 3     4.0    129
# 4     3.9    123
# 5     4.4    123
# 6     3.8     86
# 7     4.5     75
# 8       4     52
# 9     3.7     42
# 10    3.6     35
# 11    3.5     26
# 12    4.6     17
# 13    3.3     16
# 14    3.4     10
# 15    4.7      6
# 16    3.1      4
# 17    3.0      3
# 18    4.8      3
# 19    5.0      3
# 20    2.8      2
# 21    3.2      2
# 22    2.3      1
# 23      |      1
# 24      2      1
# 25      3      1
# 26    2.6      1
# 27    2.9      1

# %% [markdown]
# if we see from table given above, there's a '|' value on index 23
#
# solution :
# 1. We can search the rating online and replace it with the rating we found
# 2. We can replace it with null and later impute it with median or mean

# %%
# Solution 2
sales['rating'] = sales['rating'].replace('|', np.nan).astype(float)

# %%
# New Data Information
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# ## Handling Missing Value

# %%
sales.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 1
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# From the data given, we know that we have 3 missing data (2 rating_count and 1 rating)

# %% [markdown]
# ### Rating

# %%
# Rating missing value data
sales.query('rating.isna()')
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#                                                category  discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...            2099.0
#
#       actual_price  discount_percentage  rating  rating_count  \
# 1279        2499.0                 0.16     NaN         992.0
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# ...

# %%
# Rating Information
r_median = sales['rating'].median()
r_mean = sales['rating'].mean()

print(f'Rating Median : {r_median}')
print(f'Rating Mean : {r_mean}')
# Out:
# Rating Median : 4.1
# Rating Mean : 4.096584699453552

# %%
# Fill the missing value with median
sales['rating'] = sales['rating'].fillna(value=r_median)

# %% [markdown]
# ### Rating Count

# %%
# Rating Count missing value data
sales.query('rating_count.isna()')
# Out:
#      product_id                                       product_name  \
# 282  B0B94JPY2N  Amazon Brand - Solimo 65W Fast Charging Braide...
# 324  B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
#
#                                               category  discounted_price  \
# 282  Computers&Accessories|Accessories&Peripherals|...             199.0
# 324  Computers&Accessories|Accessories&Peripherals|...             249.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 282         999.0                 0.80     3.0           NaN
# 324         999.0                 0.75     5.0           NaN
#
#                                          about_product  \
# 282  USB C to C Cable: This cable has type C connec...
# 324  💎[The Fastest Charge] - This iPhone USB C cabl...
#
#                           user_id    user_name      review_id  \
# 282  AE7CFHY23VAJT2FI4NZKKP6GS2UQ       Pranav   RUB7U91HVZ30
# ...

# %%
# Rating Count Information
rc_median = sales['rating_count'].median()
rc_mean = sales['rating_count'].mean()

print(f'Rating Count Median : {rc_median}')
print(f'Rating Count Mean : {rc_mean}')
# Out:
# Rating Count Median : 5179.0
# Rating Count Mean : 18295.541353383458

# %%
# Fill the missing data using mean
sales.rating_count = sales.rating_count.fillna(value=rc_median)

# %% [markdown]
# ### Result

# %%
sales.isna().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           0
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# Missing value problem solved !

# %% [markdown]
# ## Checking for duplicate data

# %%
# Checking for duplicate rows
print(sales.duplicated().any())
# Out:
# False

# %%
# Checking for duplicate data each columns/features
for i in sales.columns:
    print(f'Duplicate in {i.ljust(23)}: {sales[i].duplicated().sum()}')
# Out:
# Duplicate in product_id             : 114
# Duplicate in product_name           : 128
# Duplicate in category               : 1254
# Duplicate in discounted_price       : 915
# Duplicate in actual_price           : 1016
# Duplicate in discount_percentage    : 1373
# Duplicate in rating                 : 1440
# Duplicate in rating_count           : 322
# Duplicate in about_product          : 172
# Duplicate in user_id                : 271
# Duplicate in user_name              : 271
# Duplicate in review_id              : 271
# Duplicate in review_title           : 271
# Duplicate in review_content         : 253
# Duplicate in img_link               : 53
# Duplicate in product_link           : 0

# %% [markdown]
# Key Point:
# * There are some duplicates value in the 'product_id' columns
# * Need to check other duplicate columns

# %%
# Row before removing all the dupes
rows_before = len(sales)

# %% [markdown]
# ### Product ID

# %%
dupe_id = sales['product_id'].value_counts().reset_index()
dupe_id = dupe_id.query('count > 1')
dupe_id
# Out:
#     product_id  count
# 0   B08WRWPM22      3
# 1   B01GGKYKQM      3
# 2   B09CMP1SC8      3
# 3   B09W5XR9RT      3
# 4   B09YLXYP7Y      3
# ..         ...    ...
# 87  B08Y1SJVV5      2
# 88  B09KGV7WSV      2
# 89  B09RZS1NQT      2
# 90  B0B2DJDCPX      2
# 91  B07DJLFMPS      2
#
# [92 rows x 2 columns]

# %% [markdown]
# We have 92 'product_id' that have dupe data

# %%
new_sample = sales.query('product_id == "B08WRWPM22"').reset_index()
new_sample
# Out:
#    index  product_id                                       product_name  \
# 0      6  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 1    418  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
# 2    658  B08WRWPM22  boAt Micro USB 55 Tangle-free, Sturdy Micro US...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...            176.63
# 1  Computers&Accessories|Accessories&Peripherals|...            176.63
# 2  Computers&Accessories|Accessories&Peripherals|...            176.63
#
#    actual_price  discount_percentage  rating  rating_count  \
# 0         499.0                 0.65     4.1       15188.0
# 1         499.0                 0.65     4.1       15189.0
# 2         499.0                 0.65     4.1       15189.0
#
#                                        about_product  \
# 0  It Ensures High Speed Transmission And Chargin...
# ...

# %%
# Check the detail in each columns for the dupes data
for i in new_sample.columns:
    print(f'Dupe in {i.ljust(23)}: {new_sample[i].duplicated().sum()}')
# Out:
# Dupe in index                  : 0
# Dupe in product_id             : 2
# Dupe in product_name           : 2
# Dupe in category               : 2
# Dupe in discounted_price       : 2
# Dupe in actual_price           : 2
# Dupe in discount_percentage    : 2
# Dupe in rating                 : 2
# Dupe in rating_count           : 1
# Dupe in about_product          : 2
# Dupe in user_id                : 2
# Dupe in user_name              : 2
# Dupe in review_id              : 2
# Dupe in review_title           : 2
# Dupe in review_content         : 2
# Dupe in img_link               : 1
# Dupe in product_link           : 0

# %% [markdown]
# it's weird that the product have the same id but have 1 different rating count and img link, but theres no dupe in product link

# %%
# Looking into these weird dupes data
col = ['rating_count', 'img_link', 'product_link']

for i in col:
    print(i)
    for j in range(3):
        print(new_sample[i].iloc[j])
    print('\n')
# Out:
# rating_count
# 15188.0
# 15189.0
# 15189.0
#
#
# img_link
# https://m.media-amazon.com/images/W/WEBP_402378-T2/images/I/41jlwEZpa5L._SX300_SY300_QL70_FMwebp_.jpg
# https://m.media-amazon.com/images/I/41jlwEZpa5L._SX300_SY300_QL70_ML2_.jpg
# https://m.media-amazon.com/images/W/WEBP_402378-T2/images/I/41jlwEZpa5L._SX300_SY300_QL70_FMwebp_.jpg
#
#
# product_link
# https://www.amazon.in/boAt-Micro-USB-Tangle-Free-Transmission/dp/B08WRWPM22/ref=sr_1_8?qid=1672909124&s=electronics&sr=1-8
# https://www.amazon.in/boAt-Micro-USB-Tangle-Free-Transmission/dp/B08WRWPM22/ref=sr_1_87?qid=1672895770&s=electronics&sr=1-87
# https://www.amazon.in/boAt-Micro-USB-Tangle-Free-Transmission/dp/B08WRWPM22/ref=sr_1_78?qid=1672902998&s=computers&sr=1-78

# %% [markdown]
# even thou this three data has different 'img_link' and 'product_link', all the link lead to the same product. for rating count it only different 1 value. So in conclusion this 3 data is really dupes data so we can remove them all and keep the first data

# %%
# Remove all the 'product_id' dupes from dataset
sales = sales.drop_duplicates(subset='product_id', keep='first')

# Rows after removing the dupes
rows_after_id = len(sales)

# %%
print(f'Rows before removing dupes id : {rows_before}')
print(f'Rows after removing dupes id : {rows_after_id}')
print(f'Succesfully removes {rows_before - rows_after_id} rows')
# Out:
# Rows before removing dupes id : 1465
# Rows after removing dupes id : 1351
# Succesfully removes 114 rows

# %% [markdown]
# ### Product Name

# %%
dupe_name = sales['product_name'].value_counts().reset_index()
dupe_name = dupe_name.query('count > 1')
dupe_name
# Out:
#                                         product_name  count
# 0  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...      5
# 1  Fire-Boltt Phoenix Smart Watch with Bluetooth ...      3
# 2  Samsung Galaxy M13 5G (Aqua Green, 6GB, 128GB ...      3
# 3  Redmi Note 11 (Horizon Blue, 6GB RAM, 64GB Sto...      2
# 4  Smashtronics® - Case for Firetv Remote, Fire S...      2
# 5  Fire-Boltt Visionary 1.78" AMOLED Bluetooth Ca...      2
# 6  Fire-Boltt India's No 1 Smartwatch Brand Talk ...      2
# 7  Samsung Galaxy M33 5G (Emerald Brown, 6GB, 128...      2
# 8                                   Firestick Remote      2

# %% [markdown]
# After removing all the dupe id, we have 8 remaining product_name who have dupes also

# %%
# Extract the first product name in the dataset that's have dupes
name = dupe_name['product_name'].iloc[0]
name
# Out:
# 'Fire-Boltt Ninja Call Pro Plus 1.83" Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes IP67 Rating, 240*280 Pixel High Resolution'

# %%
# Show data that have first product name duplicate
sales[sales['product_name'] == name]
# Out:
#      product_id                                       product_name  \
# 334  B0BF57RN3K  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 364  B0BF54972T  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 368  B0BF563HB4  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 372  B0BF4YBLPX  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 380  B0BF54LXW6  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
#
#                                         category  discounted_price  \
# 334  Electronics|WearableTechnology|SmartWatches            1799.0
# 364  Electronics|WearableTechnology|SmartWatches            1799.0
# 368  Electronics|WearableTechnology|SmartWatches            1799.0
# 372  Electronics|WearableTechnology|SmartWatches            1799.0
# 380  Electronics|WearableTechnology|SmartWatches            1799.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 334       19999.0                 0.91     4.2       13937.0
# ...

# %%
# Get the first dupe data in product name
new_sample = sales[sales['product_name'] == name]
new_sample
# Out:
#      product_id                                       product_name  \
# 334  B0BF57RN3K  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 364  B0BF54972T  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 368  B0BF563HB4  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 372  B0BF4YBLPX  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# 380  B0BF54LXW6  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
#
#                                         category  discounted_price  \
# 334  Electronics|WearableTechnology|SmartWatches            1799.0
# 364  Electronics|WearableTechnology|SmartWatches            1799.0
# 368  Electronics|WearableTechnology|SmartWatches            1799.0
# 372  Electronics|WearableTechnology|SmartWatches            1799.0
# 380  Electronics|WearableTechnology|SmartWatches            1799.0
#
#      actual_price  discount_percentage  rating  rating_count  \
# 334       19999.0                 0.91     4.2       13937.0
# ...

# %%
# Check the detail in each row of sample
for i in new_sample.columns:
    print(f'Dupes in {i.ljust(23)}: {new_sample[i].duplicated().sum()}')
# Out:
# Dupes in product_id             : 0
# Dupes in product_name           : 4
# Dupes in category               : 4
# Dupes in discounted_price       : 4
# Dupes in actual_price           : 4
# Dupes in discount_percentage    : 4
# Dupes in rating                 : 4
# Dupes in rating_count           : 4
# Dupes in about_product          : 2
# Dupes in user_id                : 4
# Dupes in user_name              : 4
# Dupes in review_id              : 4
# Dupes in review_title           : 4
# Dupes in review_content         : 4
# Dupes in img_link               : 0
# Dupes in product_link           : 0

# %%
# Detail in the columns that has same name but different value in some columns
col = ['about_product', 'img_link', 'product_link']

for i in col:
    print(i,':')
    for j in range(5):
        print(new_sample[i].iloc[j])
    print('\n')
# Out:
# about_product :
# ...

# %% [markdown]
# Summarize :
#
# * All the data also lead to the same data, the different in 'about_product' is there a typo of space (' ') in smartwatch.
#
# * For the img_link they show the same type but different color
#
# * Product_link only different link but same output
#
# Conclusion :
# * The data shown only have different id but all the remaining features are the same. So we need to erase them also

# %%
# Remove all the 'product_name' dupes from dataset
sales = sales.drop_duplicates(subset='product_name',keep='first')

# Rows after removing name dupes
rows_after_name = len(sales)

# %%
# Total dupes remove
print(f'Rows before removing name dupes : {rows_after_id}')
print(f'Rows after removing name dupes : {rows_after_name}')
print(f'Succesfully removes {rows_after_id - rows_after_name} rows')
# Out:
# Rows before removing name dupes : 1351
# Rows after removing name dupes : 1337
# Succesfully removes 14 rows

# %% [markdown]
# ### Duplicate re-check

# %%
# Re-check the number of duplicate in product_id and product_name
for i in sales.columns:
    print(f'Duplicates in {i.ljust(23)}: {sales[i].duplicated().sum()}')
# Out:
# Duplicates in product_id             : 0
# Duplicates in product_name           : 0
# Duplicates in category               : 1126
# Duplicates in discounted_price       : 788
# Duplicates in actual_price           : 888
# Duplicates in discount_percentage    : 1245
# Duplicates in rating                 : 1312
# Duplicates in rating_count           : 223
# Duplicates in about_product          : 53
# Duplicates in user_id                : 152
# Duplicates in user_name              : 152
# Duplicates in review_id              : 152
# Duplicates in review_title           : 152
# Duplicates in review_content         : 141
# Duplicates in img_link               : 21
# Duplicates in product_link           : 0

# %% [markdown]
# For other columns is common to have duplicate within rows cause they are not unique,
#
# for other type id data like user_id and review_id has some duplicate is okay because this data for product, so it's more weird to have product id and name have dupe. because that also people review in product A is also be a reviewer in product B.

# %% [markdown]
# # Feature Engineering

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1337 non-null   object
#  1   product_name         1337 non-null   object
#  2   category             1337 non-null   object
#  3   discounted_price     1337 non-null   float64
#  4   actual_price         1337 non-null   float64
#  5   discount_percentage  1337 non-null   float64
#  6   rating               1337 non-null   float64
#  7   rating_count         1337 non-null   float64
#  8   about_product        1337 non-null   object
#  9   user_id              1337 non-null   object
#  10  user_name            1337 non-null   object
#  11  review_id            1337 non-null   object
#  12  review_title         1337 non-null   object
#  13  review_content       1337 non-null   object
#  14  img_link             1337 non-null   object
# ...

# %%
# Extract the category in the end and begining for main category and sub category
sales['sub_category'] = sales['category'].str.split('|').str[-1]
sales['main_category'] = sales['category'].str.split('|').str[0]

# %%
# Result
sales[['category', 'main_category', 'sub_category']].head(5)
# Out:
#                                             category          main_category  \
# 0  Computers&Accessories|Accessories&Peripherals|...  Computers&Accessories
# 1  Computers&Accessories|Accessories&Peripherals|...  Computers&Accessories
# 2  Computers&Accessories|Accessories&Peripherals|...  Computers&Accessories
# 3  Computers&Accessories|Accessories&Peripherals|...  Computers&Accessories
# 4  Computers&Accessories|Accessories&Peripherals|...  Computers&Accessories
#
#   sub_category
# 0    USBCables
# 1    USBCables
# 2    USBCables
# 3    USBCables
# 4    USBCables

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1464
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1337 non-null   object
#  1   product_name         1337 non-null   object
#  2   category             1337 non-null   object
#  3   discounted_price     1337 non-null   float64
#  4   actual_price         1337 non-null   float64
#  5   discount_percentage  1337 non-null   float64
#  6   rating               1337 non-null   float64
#  7   rating_count         1337 non-null   float64
#  8   about_product        1337 non-null   object
#  9   user_id              1337 non-null   object
#  10  user_name            1337 non-null   object
#  11  review_id            1337 non-null   object
#  12  review_title         1337 non-null   object
#  13  review_content       1337 non-null   object
#  14  img_link             1337 non-null   object
# ...

# %%
# Dropping all the columns that we don't need
sales.drop(columns=['img_link', 'product_link', 'user_id', 'user_name', 'review_id'], inplace=True)
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1464
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1337 non-null   object
#  1   product_name         1337 non-null   object
#  2   category             1337 non-null   object
#  3   discounted_price     1337 non-null   float64
#  4   actual_price         1337 non-null   float64
#  5   discount_percentage  1337 non-null   float64
#  6   rating               1337 non-null   float64
#  7   rating_count         1337 non-null   float64
#  8   about_product        1337 non-null   object
#  9   review_title         1337 non-null   object
#  10  review_content       1337 non-null   object
#  11  sub_category         1337 non-null   object
#  12  main_category        1337 non-null   object
# dtypes: float64(5), object(8)
# memory usage: 146.2+ KB

# %% [markdown]
# # Data Analyze and Visualisation

# %%
# Data Description
sales.describe()
# Out:
#        discounted_price   actual_price  discount_percentage       rating  \
# count       1337.000000    1337.000000          1337.000000  1337.000000
# mean        3281.908130    5590.795527             0.465026     4.091473
# std         7183.447476   11210.427945             0.215169     0.297850
# min           39.000000      39.000000             0.000000     2.000000
# 25%          349.000000     899.000000             0.310000     3.900000
# 50%          873.000000    1700.000000             0.480000     4.100000
# 75%         2099.000000    4332.960000             0.620000     4.300000
# max        77990.000000  139900.000000             0.940000     5.000000
#
#         rating_count
# count    1337.000000
# mean    17608.456245
# std     42318.707624
# min         2.000000
# 25%      1092.000000
# 50%      4703.000000
# 75%     15646.000000
# max    426973.000000

# %%
numeric_features = ['discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count']

# %%
max_main_cat = sales.groupby('main_category')['rating'].max().sort_values()

max_main_cat.plot(kind='bar')
plt.ylabel('Rating')
plt.xlabel('Main Category')
plt.title('Rating Product for Main Category')
plt.xticks(rotation=90)
plt.show()

# %%
max_sub_cat = sales.groupby('sub_category')['rating'].max().head(5)

max_sub_cat.plot(kind='bar')
plt.xlabel('Sub Category')
plt.title('Top 5 Rating in Sub Category')
plt.show()
